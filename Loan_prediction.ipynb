# %%
import pandas as pd
import numpy as np

# %%
# !gdown 1WI-TkvTXywmevllroaxXwuBh5aCFMtne
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1WI-TkvTXywmevllroaxXwuBh5aCFMtne
#
# but Gdown can't. Please check connections and permissions.

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WI-TkvTXywmevllroaxXwuBh5aCFMtne' -O 'downloaded_file.csv'
# Out:
# --2026-03-20 08:24:09--  https://docs.google.com/uc?export=download&id=1WI-TkvTXywmevllroaxXwuBh5aCFMtne
# Resolving docs.google.com (docs.google.com)... 142.250.99.139, 142.250.99.102, 142.250.99.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.99.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1WI-TkvTXywmevllroaxXwuBh5aCFMtne&export=download [following]
# --2026-03-20 08:24:09--  https://drive.usercontent.google.com/download?id=1WI-TkvTXywmevllroaxXwuBh5aCFMtne&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.203.132, 2607:f8b0:400e:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-03-20 08:24:09 ERROR 404: Not Found.

# %%
# !pip install mlflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 85.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.1/197.1 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.5/838.5 kB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 11.3 MB/s eta 0:00:00
# ...

# %%
import mlflow
import os
mlflow.set_experiment('loan_status')
# Out:
# 2026/03/20 08:52:45 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/03/20 08:52:45 INFO mlflow.store.db.utils: Updating database tables
# 2026/03/20 08:52:47 INFO mlflow.tracking.fluent: Experiment with name 'loan_status' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/content/mlruns/1', creation_time=1773996767619, experiment_id='1', last_update_time=1773996767619, lifecycle_stage='active', name='loan_status', tags={}, workspace='default'>

# %%
with mlflow.start_run():
  model_rf = RandomForestClassifier(max_depth=4, random_state=5)
  model_rf.fit(x_train, y_train)

  pred_val = model_rf.predict(x_val)
  val_acc = accuracy_score(y_val, pred_val)

  pred_train = model_rf.predict(x_train)
  train_acc = accuracy_score(y_train, pred_train)

  mlflow.set_tag('mlflow.runName', 'first_run')
  mlflow.log_param('max_depth', 4)
  mlflow.log_param('random_state', 5)
  mlflow.sklearn.log_model(model_rf, 'model')
